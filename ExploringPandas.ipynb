# %% [markdown]
# ## Printing the first message in jupyter notebook.

# %%
print("Hello data scientists.")
# Out:
# Hello data scientists.

# %% [markdown]
# ## creating the 1 dimentional dataframe.

# %%
import pandas as pd
cars = pd.Series(['Lamborghini', 'Buggati', 'BMW', 'Maruti'])
cars
# Out:
# 0    Lamborghini
# 1        Buggati
# 2            BMW
# 3         Maruti
# dtype: object

# %%
colors = pd.Series(['Red','Green','Blue', 'Yellow'])
colors
# Out:
# 0       Red
# 1     Green
# 2      Blue
# 3    Yellow
# dtype: object

# %% [markdown]
# ## Creating two dimensional dataframe.

# %%
df = pd.DataFrame({'Cars':cars, 'Colors':colors})

# %%
df
# Out:
#           Cars  Colors
# 0  Lamborghini     Red
# 1      Buggati   Green
# 2          BMW    Blue
# 3       Maruti  Yellow

# %% [markdown]
# ## Opening the csv file.

# %%
df = pd.read_csv('/home/niraj/Desktop/data.csv')
df
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 2      virat    Kohli    virat  kholi12         Delhi  1234098756  1999-01-10
# 3       Mahi    Singh     mahi    dhoni        Ranchi  2345067890  1998-02-30
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5364853596  1998-02-30
# 6      virat    virat    virat    virat     Kathmandu  6587932040  1999-01-10
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9364594376  1998-02-30
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7084045794  1999-01-10
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4745245848  1998-02-30
# 10     virat    virat    virat    virat     Kathmandu  5703458045  1999-01-10
# ...

# %% [markdown]
# ## Describing the data

# %%
df.head()
# Out:
#   Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0     Niraj   Poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1     Niraj  Chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 2     virat    Kohli    virat  kholi12         Delhi  1234098756  1999-01-10
# 3      Mahi    Singh     mahi    dhoni        Ranchi  2345067890  1998-02-30
# 4     Niraj    Niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
#
#                       Email    Zip
# 0  nirajpoudel100@gmail.com  123.0
# 1              nj@gmail.com  456.0
# 2           virat@gmail.com  789.0
# 3  nirajpoudel100@gmail.com  987.0
# 4              nj@gmail.com  654.0

# %%
df.tail()
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 11      Mahi     Mahi     Mahi     Mahi         Delhi  6498903479  1998-02-30
# 12     Niraj    Niraj    Niraj    Niraj        Ranchi  4709639449  1999-01-10
# 13     Niraj    Niraj    Niraj    Niraj       pokhara  3456783333  1998-02-30
# 14     virat    virat    virat    virat  Arghakhanchi  1234568650  1999-01-10
# 15      Mahi     Mahi     Mahi     Mahi     Kathmandu   874646467  1998-02-30
#
#                        Email    Zip
# 11           virat@gmail.com  760.0
# 12  nirajpoudel100@gmail.com  456.0
# 13              nj@gmail.com  567.0
# 14           virat@gmail.com    NaN
# 15        niraj123@gmail.com    NaN

# %%
df.head(10)
# Out:
#   Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0     Niraj   Poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1     Niraj  Chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 2     virat    Kohli    virat  kholi12         Delhi  1234098756  1999-01-10
# 3      Mahi    Singh     mahi    dhoni        Ranchi  2345067890  1998-02-30
# 4     Niraj    Niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
# 5     Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5364853596  1998-02-30
# 6     virat    virat    virat    virat     Kathmandu  6587932040  1999-01-10
# 7      Mahi     Mahi     Mahi     Mahi         Delhi  9364594376  1998-02-30
# 8     Niraj    Niraj    Niraj    Niraj        Ranchi  7084045794  1999-01-10
# 9     Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4745245848  1998-02-30
#
#                       Email    Zip
# 0  nirajpoudel100@gmail.com  123.0
# 1              nj@gmail.com  456.0
# ...

# %%
df.describe()
# Out:
#             Contact         Zip
# count  1.600000e+01   14.000000
# mean   4.691005e+09  558.214286
# std    2.830214e+09  258.686379
# min    8.746465e+08  123.000000
# 25%    2.067443e+09  354.750000
# 50%    4.747796e+09  567.000000
# 75%    6.521161e+09  758.500000
# max    9.867331e+09  987.000000

# %%
df.dtypes
# Out:
# Firstname       object
# Lastname        object
# Username        object
# Password        object
# Address         object
# Contact          int64
# DateOfBirth     object
# Email           object
# Zip            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Firstname    16 non-null     object
#  1   Lastname     16 non-null     object
#  2   Username     16 non-null     object
#  3   Password     16 non-null     object
#  4   Address      16 non-null     object
#  5   Contact      16 non-null     int64
#  6   DateOfBirth  16 non-null     object
#  7   Email        16 non-null     object
#  8   Zip          14 non-null     float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 1.2+ KB

# %% [markdown]
# ## Statistical analysis of data.

# %%
df.mean()
# Out:
# Contact    4.691005e+09
# Zip        5.582143e+02
# dtype: float64

# %%
df.median()
# Out:
# Contact    4.747796e+09
# Zip        5.670000e+02
# dtype: float64

# %%
df.mode()
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0      Niraj    Niraj    Niraj    Niraj  Arghakhanchi   874646467  1998-02-30
# 1        NaN      NaN      NaN      NaN     Kathmandu  1234098756  1999-01-10
# 2        NaN      NaN      NaN      NaN           NaN  1234567890         NaN
# 3        NaN      NaN      NaN      NaN           NaN  1234568650         NaN
# 4        NaN      NaN      NaN      NaN           NaN  2345067890         NaN
# 5        NaN      NaN      NaN      NaN           NaN  3456783333         NaN
# 6        NaN      NaN      NaN      NaN           NaN  4709639449         NaN
# 7        NaN      NaN      NaN      NaN           NaN  4745245848         NaN
# 8        NaN      NaN      NaN      NaN           NaN  4750345834         NaN
# 9        NaN      NaN      NaN      NaN           NaN  5364853596         NaN
# 10       NaN      NaN      NaN      NaN           NaN  5703458045         NaN
# ...

# %%
df.std()
# Out:
# Contact    2.830214e+09
# Zip        2.586864e+02
# dtype: float64

# %% [markdown]
# ## Statistical analysis using index

# %%
df['Zip'].mean()
# Out:
# 558.2142857142857

# %%
df['Zip'].std()
# Out:
# 258.6863793421348

# %%
df['Contact'].mode()
# Out:
# 0      874646467
# 1     1234098756
# 2     1234567890
# 3     1234568650
# 4     2345067890
# 5     3456783333
# 6     4709639449
# 7     4745245848
# 8     4750345834
# 9     5364853596
# 10    5703458045
# 11    6498903479
# 12    6587932040
# 13    7084045794
# 14    9364594376
# 15    9867330664
# dtype: int64

# %%
df['Contact'].median()
# Out:
# 4747795841.0

# %% [markdown]
# ## Changing and Copying the values into new csv file.

# %%
df['Zip'] = 1
df
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 2      virat    Kohli    virat  kholi12         Delhi  1234098756  1999-01-10
# 3       Mahi    Singh     mahi    dhoni        Ranchi  2345067890  1998-02-30
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5364853596  1998-02-30
# 6      virat    virat    virat    virat     Kathmandu  6587932040  1999-01-10
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9364594376  1998-02-30
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7084045794  1999-01-10
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4745245848  1998-02-30
# 10     virat    virat    virat    virat     Kathmandu  5703458045  1999-01-10
# ...

# %%
df1 = df.to_csv('/home/niraj/Desktop/NewData.csv')

# %%
df
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 2      virat    Kohli    virat  kholi12         Delhi  1234098756  1999-01-10
# 3       Mahi    Singh     mahi    dhoni        Ranchi  2345067890  1998-02-30
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5364853596  1998-02-30
# 6      virat    virat    virat    virat     Kathmandu  6587932040  1999-01-10
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9364594376  1998-02-30
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7084045794  1999-01-10
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4745245848  1998-02-30
# 10     virat    virat    virat    virat     Kathmandu  5703458045  1999-01-10
# ...

# %%
len(df)
# Out:
# 16

# %%
df.loc[10]
# Out:
# Firstname             virat
# Lastname              virat
# Username              virat
# Password              virat
# Address           Kathmandu
# Contact          5703458045
# DateOfBirth      1999-01-10
# Email          nj@gmail.com
# Zip                       1
# Name: 10, dtype: object

# %%
df[df['Firstname'] == 'Niraj']
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5364853596  1998-02-30
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7084045794  1999-01-10
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4745245848  1998-02-30
# 12     Niraj    Niraj    Niraj    Niraj        Ranchi  4709639449  1999-01-10
# 13     Niraj    Niraj    Niraj    Niraj       pokhara  3456783333  1998-02-30
#
#                        Email  Zip
# 0   nirajpoudel100@gmail.com    1
# 1               nj@gmail.com    1
# 4               nj@gmail.com    1
# 5            virat@gmail.com    1
# 8            virat@gmail.com    1
# 9   nirajpoudel100@gmail.com    1
# ...

# %%
df
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 2      virat    Kohli    virat  kholi12         Delhi  1234098756  1999-01-10
# 3       Mahi    Singh     mahi    dhoni        Ranchi  2345067890  1998-02-30
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5364853596  1998-02-30
# 6      virat    virat    virat    virat     Kathmandu  6587932040  1999-01-10
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9364594376  1998-02-30
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7084045794  1999-01-10
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4745245848  1998-02-30
# 10     virat    virat    virat    virat     Kathmandu  5703458045  1999-01-10
# ...

# %% [markdown]
# ## Comparing two columns

# %%
pd.crosstab(df['Firstname'],df['Lastname'])
# Out:
# Lastname   Chudali  Kohli  Mahi  Niraj  Poudel  Singh  virat
# Firstname
# Mahi             0      0     3      0       0      1      0
# Niraj            1      0     0      6       1      0      0
# virat            0      1     0      0       0      0      3

# %% [markdown]
# ## Comparing more than two colums.

# %%
df.groupby(['Firstname']).mean()
# Out:
#                 Contact  Zip
# Firstname
# Mahi       4.770803e+09  1.0
# Niraj      5.151602e+09  1.0
# virat      3.690014e+09  1.0

# %%
df.groupby(['Lastname']).median()
# Out:
#              Contact  Zip
# Lastname
# Chudali   1234567890    1
# Kohli     1234098756    1
# Mahi      6498903479    1
# Niraj     4747795841    1
# Poudel    9867330664    1
# Singh     2345067890    1
# virat     5703458045    1

# %%
pd.crosstab(df['Lastname'],df['Zip'])
# Out:
# Zip       1
# Lastname
# Chudali   1
# Kohli     1
# Mahi      3
# Niraj     6
# Poudel    1
# Singh     1
# virat     3

# %% [markdown]
# ## Plotting the information using matplotlib library.

# %%
import matplotlib.pyplot as plt
df['Zip'].plot()

# %%
df = pd.read_csv('/home/niraj/Desktop/data.csv')

# %%
df
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 2      virat    Kohli    virat  kholi12         Delhi  1234098756  1999-01-10
# 3       Mahi    Singh     mahi    dhoni        Ranchi  2345067890  1998-02-30
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5364853596  1998-02-30
# 6      virat    virat    virat    virat     Kathmandu  6587932040  1999-01-10
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9364594376  1998-02-30
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7084045794  1999-01-10
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4745245848  1998-02-30
# 10     virat    virat    virat    virat     Kathmandu  5703458045  1999-01-10
# ...

# %%
df.plot()

# %%
df['Zip'].plot()

# %%
df['Zip'].hist()

# %% [markdown]
# ## Manipulating data with pandas.

# %%
df
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 2      virat    Kohli    virat  kholi12         Delhi  1234098756  1999-01-10
# 3       Mahi    Singh     mahi    dhoni        Ranchi  2345067890  1998-02-30
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5364853596  1998-02-30
# 6      virat    virat    virat    virat     Kathmandu  6587932040  1999-01-10
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9364594376  1998-02-30
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7084045794  1999-01-10
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4745245848  1998-02-30
# 10     virat    virat    virat    virat     Kathmandu  5703458045  1999-01-10
# ...

# %%
df['Firstname'].str.lower()
# Out:
# 0     niraj
# 1     niraj
# 2     virat
# 3      mahi
# 4     niraj
# 5     niraj
# 6     virat
# 7      mahi
# 8     niraj
# 9     niraj
# 10    virat
# 11     mahi
# 12    niraj
# 13    niraj
# 14    virat
# 15     mahi
# Name: Firstname, dtype: object

# %%
df['Lastname'].str.upper()
# Out:
# 0      POUDEL
# 1     CHUDALI
# 2       KOHLI
# 3       SINGH
# 4       NIRAJ
# 5       NIRAJ
# 6       VIRAT
# 7        MAHI
# 8       NIRAJ
# 9       NIRAJ
# 10      VIRAT
# 11       MAHI
# 12      NIRAJ
# 13      NIRAJ
# 14      VIRAT
# 15       MAHI
# Name: Lastname, dtype: object

# %% [markdown]
# ## To save the value in either upper or lower case.

# %%
df['Lastname'] = df['Lastname'].str.lower()

# %%
df
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0      Niraj   poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1      Niraj  chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 2      virat    kohli    virat  kholi12         Delhi  1234098756  1999-01-10
# 3       Mahi    singh     mahi    dhoni        Ranchi  2345067890  1998-02-30
# 4      Niraj    niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
# 5      Niraj    niraj    Niraj    Niraj  Arghakhanchi  5364853596  1998-02-30
# 6      virat    virat    virat    virat     Kathmandu  6587932040  1999-01-10
# 7       Mahi     mahi     Mahi     Mahi         Delhi  9364594376  1998-02-30
# 8      Niraj    niraj    Niraj    Niraj        Ranchi  7084045794  1999-01-10
# 9      Niraj    niraj    Niraj    Niraj  Arghakhanchi  4745245848  1998-02-30
# 10     virat    virat    virat    virat     Kathmandu  5703458045  1999-01-10
# ...

# %%
df['Firstname'] = df['Firstname'].str.upper()
df
# Out:
#    Firstname Lastname Username Password       Address     Contact DateOfBirth  \
# 0      NIRAJ   poudel   @niraj      123  Arghakhanchi  9867330664  1999-01-10
# 1      NIRAJ  chudali       nj     nj18     Kathmandu  1234567890  1998-02-30
# 2      VIRAT    kohli    virat  kholi12         Delhi  1234098756  1999-01-10
# 3       MAHI    singh     mahi    dhoni        Ranchi  2345067890  1998-02-30
# 4      NIRAJ    niraj    Niraj    Niraj  sandhikharka  4750345834  1999-01-10
# 5      NIRAJ    niraj    Niraj    Niraj  Arghakhanchi  5364853596  1998-02-30
# 6      VIRAT    virat    virat    virat     Kathmandu  6587932040  1999-01-10
# 7       MAHI     mahi     Mahi     Mahi         Delhi  9364594376  1998-02-30
# 8      NIRAJ    niraj    Niraj    Niraj        Ranchi  7084045794  1999-01-10
# 9      NIRAJ    niraj    Niraj    Niraj  Arghakhanchi  4745245848  1998-02-30
# 10     VIRAT    virat    virat    virat     Kathmandu  5703458045  1999-01-10
# ...

# %% [markdown]
# ## Messing Data

# %%
data_frame = pd.read_csv('/home/niraj/Desktop/data.csv')

# %%
data_frame
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
data_frame['Zip'].fillna(data_frame['Zip'].mean())
# Out:
# 0     123.000000
# 1     456.000000
# 2     789.000000
# 3     987.000000
# 4     654.000000
# 5     321.000000
# 6     234.000000
# 7     567.000000
# 8     754.000000
# 9     867.000000
# 10    280.000000
# 11    760.000000
# 12    456.000000
# 13    567.000000
# 14    558.214286
# 15    558.214286
# Name: Zip, dtype: float64

# %%
data_frame
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df = pd.read_csv('/home/niraj/Desktop/data.csv')

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df['Zip'].fillna(df['Zip'].mean())
# Out:
# 0     123.000000
# 1     456.000000
# 2     789.000000
# 3     987.000000
# 4     654.000000
# 5     321.000000
# 6     234.000000
# 7     567.000000
# 8     754.000000
# 9     867.000000
# 10    280.000000
# 11    760.000000
# 12    456.000000
# 13    567.000000
# 14    558.214286
# 15    558.214286
# Name: Zip, dtype: float64

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df['Zip'].fillna(df['Zip'].mean(), inplace = True)

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df.dropna()
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 14     virat    virat    virat    virat  Arghakhanchi  1.234569e+09
# 15      Mahi     Mahi     Mahi     Mahi     Kathmandu  8.746465e+08
#
#    DateOfBirth                     Email         Zip
# 0   1999-01-10  nirajpoudel100@gmail.com  123.000000
# 1   1998-02-30              nj@gmail.com  456.000000
# 4   1999-01-10              nj@gmail.com  654.000000
# ...

# %% [markdown]
# ## Create data column to the existing data.

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df1 = pd.Series(['M', 'F', 'F','M','F'])
df['Gender'] = df1

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df.dropna()
# Out:
#   Firstname Lastname Username Password       Address       Contact  \
# 0     Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1     Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 4     Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
#
#   DateOfBirth                     Email    Zip Gender
# 0  1999-01-10  nirajpoudel100@gmail.com  123.0      M
# 1  1998-02-30              nj@gmail.com  456.0      F
# 4  1999-01-10              nj@gmail.com  654.0      F

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
save_dataframe = df.to_csv('/home/niraj/Desktop/data1.csv')

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df['Gender'].fillna('M', inplace = True)

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df['Work Place'] = 'Home'

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df['Work Place'].dropna()
# Out:
# 0     Home
# 1     Home
# 2     Home
# 3     Home
# 4     Home
# 5     Home
# 6     Home
# 7     Home
# 8     Home
# 9     Home
# 10    Home
# 11    Home
# 12    Home
# 13    Home
# 14    Home
# 15    Home
# Name: Work Place, dtype: object

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df.drop('Work Place',axis = True)
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df = df.drop(['Work Place'], axis = 1)

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df['Average'] = df['Contact'] + df['Zip']

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %%
df = df.drop(['Average'], axis = 1)

# %%
df
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4      Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6      virat    virat    virat    virat     Kathmandu           NaN
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8      Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# ...

# %% [markdown]
# ## Shuffling the data

# %%
#finding 50% of the data.
df.sample(frac = 0.5)
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 5      Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# 12     Niraj    Niraj    Niraj    Niraj           NaN  4.709639e+09
# 1      Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 3       Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 14     virat    virat    virat    virat  Arghakhanchi  1.234569e+09
# 7       Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 2      virat    Kohli    virat  kholi12         Delhi           NaN
#
#    DateOfBirth                     Email    Zip Gender
# 5   1998-02-30           virat@gmail.com  321.0      5
# 10  1999-01-10              nj@gmail.com  280.0      5
# 12  1999-01-10  nirajpoudel100@gmail.com  456.0      5
# 1   1998-02-30              nj@gmail.com  456.0      F
# 3   1998-02-30  nirajpoudel100@gmail.com  987.0      M
# ...

# %%
#only 10% of the data
df.sample(frac = 0.1)
# Out:
#    Firstname Lastname Username Password       Address       Contact  \
# 11      Mahi      NaN      NaN     Mahi         Delhi  6.498903e+09
# 0      Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
#
#    DateOfBirth                     Email    Zip
# 11  1998-02-30           virat@gmail.com  760.0
# 0   1999-01-10  nirajpoudel100@gmail.com  123.0

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#     index Firstname Lastname Username Password       Address       Contact  \
# 0       0     Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1       1     Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2       2     virat    Kohli    virat  kholi12         Delhi           NaN
# 3       3      Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4       4     Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5       5     Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6       6     virat    virat    virat    virat     Kathmandu           NaN
# 7       7      Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8       8     Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9       9     Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# ...

# %%
df
# Out:
#     index Firstname Lastname Username Password       Address       Contact  \
# 0       0     Niraj   Poudel   @niraj      123  Arghakhanchi  9.867331e+09
# 1       1     Niraj  Chudali       nj     nj18     Kathmandu  1.234568e+09
# 2       2     virat    Kohli    virat  kholi12         Delhi           NaN
# 3       3      Mahi    Singh     mahi    dhoni        Ranchi           NaN
# 4       4     Niraj    Niraj    Niraj    Niraj  sandhikharka  4.750346e+09
# 5       5     Niraj    Niraj    Niraj    Niraj  Arghakhanchi  5.364854e+09
# 6       6     virat    virat    virat    virat     Kathmandu           NaN
# 7       7      Mahi     Mahi     Mahi     Mahi         Delhi  9.364594e+09
# 8       8     Niraj    Niraj    Niraj    Niraj        Ranchi  7.084046e+09
# 9       9     Niraj    Niraj    Niraj    Niraj  Arghakhanchi  4.745246e+09
# 10     10     virat    virat    virat    virat     Kathmandu  5.703458e+09
# ...
